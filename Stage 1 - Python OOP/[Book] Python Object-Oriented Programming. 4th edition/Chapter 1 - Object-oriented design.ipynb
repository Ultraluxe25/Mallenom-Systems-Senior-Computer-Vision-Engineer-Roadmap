# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Book:
    def __init__(self, title: str, edition: int, chapters: list[str]):
        self.title = title
        self.edition = edition
        self.chapters = chapters

# %% [markdown]
# Объект - это экземпляр некоторого класса, имеющий определенные свойства (поля) и выполняющий определенные действия (методы). Поля и методы = атрибуты класса.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ООП тип объекта называется классом.

# %% [markdown]
# Мы судим о состоянии объекта по его атрибутам.

# %% [markdown]
# Атрибуты могут также обозначать коллекции: списки, деревья и графы - и даже, что очень важно, неуниверсальные,
# специфические для данного приложения классы.
#
# ```python
# zones: list[AsutpZone] = Field(default_factory=list)  # pydantic.Field
# """Список зон АСУТП."""
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from datetime import datetime


class Orange:
    weight: float
    place: str
    gather_date: datetime
    basket: Basket  # type: ignore


class Basket:
    location: str
    oranges: list[Orange]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Apple:
    color: str
    weight: float
    barrel: Barrel  # type: ignore


class Barrel:
    dimension: int
    apples: list[Apple]
