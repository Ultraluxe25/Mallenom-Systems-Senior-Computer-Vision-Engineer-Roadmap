# %% [markdown]
# ![image.png](attachment:image.png)
# # Российский экономический университет им. Г.В. Плеханова

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### Переменные в Python похожи на указатели в С++ (ссылка на объект в памяти компьютера)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
